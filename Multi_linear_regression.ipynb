# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
a = files.upload()
# Out:
#      <input type="file" id="files-2e0662c3-ed04-43ce-a643-b54c7ad04197" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e0662c3-ed04-43ce-a643-b54c7ad04197">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_excel ('age.xlsx')

# %%
data
# Out:
#     age  Weight (kg)  Height (cm)  Standard
# 0    15           60          165        10
# 1    13           50          155         9
# 2     9           40          140         5
# 3    15           60          165        10
# 4    14           55          160         9
# 5    17           70          175        12
# 6    14           55          160         9
# 7     8           35          130         4
# 8    10           40          140         5
# 9    13           50          155         9
# 10   16           65          170        11
# 11    5           30          125         3
# 12   12           45          145         6
# 13   17           70          175        12
# 14    8           35          130         4
# 15    7           30          125         3
# 16   11           45          145         6
# 17    5           30          125         3
# 18    5           30          125         3
# 19   15           60          165        10
# ...

# %%
data.head()
# Out:
#    age  Weight (kg)  Height (cm)  Standard
# 0   15           60          165        10
# 1   13           50          155         9
# 2    9           40          140         5
# 3   15           60          165        10
# 4   14           55          160         9

# %%
data.tail()
# Out:
#     age  Weight (kg)  Height (cm)  Standard
# 19   15           60          165        10
# 20   16           65          170        11
# 21   13           50          155         9
# 22   15           60          165        10
# 23   11           45          145         6

# %%
data.describe()
# Out:
#              age  Weight (kg)  Height (cm)   Standard
# count  24.000000    24.000000    24.000000  24.000000
# mean   11.833333    48.958333   150.416667   7.458333
# std     3.886058    13.185892    17.189270   3.134370
# min     5.000000    30.000000   125.000000   3.000000
# 25%     8.750000    38.750000   137.500000   4.750000
# 50%    13.000000    50.000000   155.000000   9.000000
# 75%    15.000000    60.000000   165.000000  10.000000
# max    17.000000    70.000000   175.000000  12.000000

# %%
a = data.iloc[:,1:4].values

# %%
a
# Out:
# array([[ 60, 165,  10],
#        [ 50, 155,   9],
#        [ 40, 140,   5],
#        [ 60, 165,  10],
#        [ 55, 160,   9],
#        [ 70, 175,  12],
#        [ 55, 160,   9],
#        [ 35, 130,   4],
#        [ 40, 140,   5],
#        [ 50, 155,   9],
#        [ 65, 170,  11],
#        [ 30, 125,   3],
#        [ 45, 145,   6],
#        [ 70, 175,  12],
#        [ 35, 130,   4],
#        [ 30, 125,   3],
#        [ 45, 145,   6],
#        [ 30, 125,   3],
#        [ 30, 125,   3],
#        [ 60, 165,  10],
#        [ 65, 170,  11],
#        [ 50, 155,   9],
#        [ 60, 165,  10],
#        [ 45, 145,   6]])

# %%
b = data.iloc[:,:1]

# %%
b
# Out:
#     age
# 0    15
# 1    13
# 2     9
# 3    15
# 4    14
# 5    17
# 6    14
# 7     8
# 8    10
# 9    13
# 10   16
# 11    5
# 12   12
# 13   17
# 14    8
# 15    7
# 16   11
# 17    5
# 18    5
# 19   15
# 20   16
# 21   13
# 22   15
# 23   11

# %%
from sklearn.model_selection import train_test_split

# %%
a_train,a_test,b_train,b_test = train_test_split(a,b,test_size=0.3,random_state=13)

# %%
a_train.shape
# Out:
# (16, 3)

# %%
from sklearn.linear_model import LinearRegression

# %%
s_regression = LinearRegression()

# %%
s_regression.fit(a_train, b_train)
# Out:
# LinearRegression()

# %%
result = s_regression.predict(a_test)

# %%
result
# Out:
# array([[ 6.43218807],
#        [12.81916817],
#        [ 7.49728752],
#        [ 9.77034358],
#        [ 6.43218807],
#        [16.15913201],
#        [15.09403255],
#        [17.22423146]])

# %%
b_test
# Out:
#     age
# 17    5
# 1    13
# 7     8
# 8    10
# 11    5
# 20   16
# 0    15
# 13   17
